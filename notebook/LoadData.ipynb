# %%
import pandas as pd

# %%
df = pd.read_csv('../data/fraudTest.csv')

# %% [markdown]
# ## 1. Data Inspection (Understanding your data)

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800429e+14       9.630000   26292.000000
# 50%    277859.000000  3.521417e+15      47.290000   48174.000000
# 75%    416788.500000  4.635331e+15      83.010000   72011.000000
# max    555718.000000  4.992346e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
# Check data types and missing values
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  str
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  str
#  4   category               555719 non-null  str
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  str
#  7   last                   555719 non-null  str
#  8   gender                 555719 non-null  str
#  9   street                 555719 non-null  str
#  10  city                   555719 non-null  str
#  11  state                  555719 non-null  str
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
#  14  long                   555719 non-null  float64
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
# Drop unnecessary columns
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## 2. Basic Data Cleaning

# %%
# Convert date columns to datetime
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
df['dob'] = pd.to_datetime(df['dob'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  555719 non-null  datetime64[us]
#  1   cc_num                 555719 non-null  int64
#  2   merchant               555719 non-null  str
#  3   category               555719 non-null  str
#  4   amt                    555719 non-null  float64
#  5   first                  555719 non-null  str
#  6   last                   555719 non-null  str
#  7   gender                 555719 non-null  str
#  8   street                 555719 non-null  str
#  9   city                   555719 non-null  str
#  10  state                  555719 non-null  str
#  11  zip                    555719 non-null  int64
#  12  lat                    555719 non-null  float64
#  13  long                   555719 non-null  float64
# ...

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Target Distribution (Check for class imbalance)
sns.countplot(x='is_fraud', data=df)
plt.title("Distribution of Fraud vs. Normal Transaction")
plt.show()

# %%
# 2. Transaction Amount Analysis
plt.figure(figsize=(10,6))
sns.boxplot(x='is_fraud', y='amt', data=df)
plt.title('Transaction amt : Fraud vs Normal')
plt.yscale('log')
plt.show()

# %%
# 3. Fraud by Category
plt.figure(figsize=(12,6))
sns.countplot(y='category', hue='is_fraud', data=df)
plt.title('Fraud counts by Cat')
plt.show()

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Extract hour, day, and month from transaction time
df['trans_hour'] = df['trans_date_trans_time'].dt.hour
df['trans_day'] = df['trans_date_trans_time'].dt.dayofweek

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num  \
# 0   2020-06-21 12:14:25  2291163933867244
# 1   2020-06-21 12:14:33  3573030041201292
# 2   2020-06-21 12:14:53  3598215285024754
# 3   2020-06-21 12:15:15  3591919803438423
# 4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city  ... city_pop  \
# 0   Elliott      M            351 Darlene Green    Columbia  ...   333497
# 1  Williams      F             3638 Marsh Union     Altonah  ...      302
# ...

# %%
# Calculate Age of the person
df['age'] = (df['trans_date_trans_time'] - df
